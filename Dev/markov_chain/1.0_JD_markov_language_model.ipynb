# %%
# packages
import random
from collections import defaultdict

# %%
# load in data
file_loc = '../../Data/Raw/wikisent2.txt'
fp = open(file_loc, 'r')
with open(file_loc) as f:
    content = [line.rstrip('\n') for line in f]

# %%
print(len(content))
# Out:
# 7871825

# %%
# pick random sentences
random.shuffle(content)
samp = content[0:1000]

# %%
samp
# Out:
# ['Blue Parlan is an album by American jazz pianist Horace Parlan featuring performances recorded in 1978 and released on the Danish-based SteepleChase label.',
#  "It is similar to the UK's Gillette defense and the U.S. Wilson case.",
#  "D. Moses (born September 3, 1976) is a former professional football player for the NFL's New York Jets and the NFL Europe's Frankfurt Galaxy .",
#  'The American Physical Therapy Association (APTA) is a U.S-based individual membership professional organization representing more than 100,000 member physical therapists, physical therapist assistants, and students of physical therapy.',
#  'The club entered the Ukrainian Amateur Championships in 2008.',
#  'Such sources do not present a coherent, consistent definition of primary colors since real primaries cannot be complete.',
#  "It remained in the family's ownership until the death of Holdsworth's nephew in 1920.",
# ...
